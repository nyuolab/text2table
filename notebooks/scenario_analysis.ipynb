# %%
from utils.analysis import scenario_analysis

# %%
df = scenario_analysis("PROC_ICD9")
df
# Out:
#                   top50 bottom50
# BERT       +CPT   0.333    0.273
#            +DRG    0.28    0.413
#            +DIAG    0.3    0.387
# RoBERTa    +CPT     0.4      0.3
#            +DRG   0.393    0.353
#            +DIAG  0.313    0.287
# Longformer +CPT    0.34    0.427
#            +DRG    0.34     0.28
#            +DIAG  0.347    0.307

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.333 &    0.273 \\
#            & +DRG &   0.28 &    0.413 \\
#            & +DIAG &    0.3 &    0.387 \\
# RoBERTa & +CPT &    0.4 &      0.3 \\
#            & +DRG &  0.393 &    0.353 \\
#            & +DIAG &  0.313 &    0.287 \\
# Longformer & +CPT &   0.34 &    0.427 \\
#            & +DRG &   0.34 &     0.28 \\
#            & +DIAG &  0.347 &    0.307 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("DIAG_ICD9")
df
# Out:
#                   top50 bottom50
# BERT       +CPT   0.453     0.32
#            +DRG    0.54    0.293
#            +PROC   0.48     0.38
# RoBERTa    +CPT    0.48    0.313
#            +DRG   0.507    0.307
#            +PROC   0.48    0.333
# Longformer +CPT     0.5     0.32
#            +DRG    0.48    0.393
#            +PROC  0.433    0.287

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.453 &     0.32 \\
#            & +DRG &   0.54 &    0.293 \\
#            & +PROC &   0.48 &     0.38 \\
# RoBERTa & +CPT &   0.48 &    0.313 \\
#            & +DRG &  0.507 &    0.307 \\
#            & +PROC &   0.48 &    0.333 \\
# Longformer & +CPT &    0.5 &     0.32 \\
#            & +DRG &   0.48 &    0.393 \\
#            & +PROC &  0.433 &    0.287 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("PROC_ICD9", corrloss=True)
df
# Out:
#                   top50 bottom50
# BERT       +CPT   0.347     0.36
#            +DRG   0.327    0.313
#            +DIAG  0.273     0.28
# RoBERTa    +CPT    0.32     0.32
#            +DRG   0.353     0.36
#            +DIAG  0.273     0.22
# Longformer +CPT   0.353    0.367
#            +DRG    0.28    0.293
#            +DIAG  0.307     0.26

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.347 &     0.36 \\
#            & +DRG &  0.327 &    0.313 \\
#            & +DIAG &  0.273 &     0.28 \\
# RoBERTa & +CPT &   0.32 &     0.32 \\
#            & +DRG &  0.353 &     0.36 \\
#            & +DIAG &  0.273 &     0.22 \\
# Longformer & +CPT &  0.353 &    0.367 \\
#            & +DRG &   0.28 &    0.293 \\
#            & +DIAG &  0.307 &     0.26 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("DIAG_ICD9", corrloss=True)
df
# Out:
#                   top50 bottom50
# BERT       +CPT   0.413    0.307
#            +DRG   0.533     0.28
#            +PROC  0.487    0.293
# RoBERTa    +CPT    0.46      0.3
#            +DRG   0.493    0.373
#            +PROC  0.473     0.34
# Longformer +CPT   0.453    0.293
#            +DRG   0.487     0.34
#            +PROC    0.5    0.307

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.413 &    0.307 \\
#            & +DRG &  0.533 &     0.28 \\
#            & +PROC &  0.487 &    0.293 \\
# RoBERTa & +CPT &   0.46 &      0.3 \\
#            & +DRG &  0.493 &    0.373 \\
#            & +PROC &  0.473 &     0.34 \\
# Longformer & +CPT &  0.453 &    0.293 \\
#            & +DRG &  0.487 &     0.34 \\
#            & +PROC &    0.5 &    0.307 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("PROC_ICD9", correlation=True)
df
# Out:
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
# ...

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.467 &     0.32 \\
#            & +DRG &  0.307 &    0.373 \\
#            & +DIAG &  0.367 &    0.287 \\
# RoBERTa & +CPT &  0.387 &    0.267 \\
#            & +DRG &  0.413 &    0.407 \\
#            & +DIAG &   0.32 &    0.307 \\
# Longformer & +CPT &  0.427 &    0.367 \\
#            & +DRG &   0.34 &    0.307 \\
#            & +DIAG &   0.42 &    0.307 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("DIAG_ICD9", correlation=True)
df
# Out:
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
# ...

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.507 &    0.333 \\
#            & +DRG &  0.493 &    0.287 \\
#            & +PROC &  0.473 &    0.347 \\
# RoBERTa & +CPT &   0.48 &    0.247 \\
#            & +DRG &  0.513 &     0.36 \\
#            & +PROC &   0.46 &    0.347 \\
# Longformer & +CPT &  0.487 &    0.313 \\
#            & +DRG &  0.493 &     0.34 \\
#            & +PROC &  0.427 &    0.313 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("PROC_ICD9", corrloss=True, correlation=True)
df
# Out:
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
# ...

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.333 &    0.327 \\
#            & +DRG &   0.32 &    0.327 \\
#            & +DIAG &  0.293 &    0.247 \\
# RoBERTa & +CPT &  0.487 &    0.333 \\
#            & +DRG &  0.373 &    0.387 \\
#            & +DIAG &  0.267 &    0.293 \\
# Longformer & +CPT &  0.433 &    0.327 \\
#            & +DRG &   0.28 &    0.273 \\
#            & +DIAG &  0.333 &     0.24 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())

# %%
df = scenario_analysis("DIAG_ICD9", corrloss=True, correlation=True)
df
# Out:
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   correlations = correlations.to_dict('list')
# /gpfs/data/oermannlab/users/yangz09/summer/text2table/utils/analysis.py:103: UserWarning: DataFrame columns are not unique, some columns will be omitted.
# ...

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#            &       &  top50 & bottom50 \\
# \midrule
# BERT & +CPT &  0.467 &    0.373 \\
#            & +DRG &   0.52 &      0.3 \\
#            & +PROC &   0.46 &    0.333 \\
# RoBERTa & +CPT &  0.493 &     0.32 \\
#            & +DRG &   0.52 &    0.433 \\
#            & +PROC &  0.473 &    0.253 \\
# Longformer & +CPT &   0.46 &     0.32 \\
#            & +DRG &  0.513 &    0.467 \\
#            & +PROC &  0.453 &     0.34 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_181438/2350534188.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(df.to_latex())
