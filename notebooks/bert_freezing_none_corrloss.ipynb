# %%
from utils import graph

# %%
graph.micro_performance_plot("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "PROC_ICD9")

# %%
graph.micro_performance_plot("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "DIAG_ICD9")

# %%
graph.micro_performance_plot("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "PROC_ICD9", True)

# %%
graph.micro_performance_plot("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "DIAG_ICD9", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "CPT_CD")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "DRG_CODE")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "DIAG_ICD9")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "CPT_CD")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "DRG_CODE")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "PROC_ICD9")

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "CPT_CD", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "DRG_CODE", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "PROC_ICD9", "DIAG_ICD9", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "CPT_CD", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "DRG_CODE", True)

# %%
graph.label_performance_change("../language_model/Bio_Discharge_Summary_BERT_n_corrloss", "../utils/balance", "../utils/correlation", "DIAG_ICD9", "PROC_ICD9", True)
