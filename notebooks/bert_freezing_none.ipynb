# %%
from utils import graph

# %%
graph.micro_performance_plot("../BERT/Bio_Discharge_Summary_BERT_n", "PROC_ICD9")

# %%
graph.micro_performance_plot("../BERT/Bio_Discharge_Summary_BERT_n", "DIAG_ICD9")

# %%
graph.micro_performance_plot("../BERT/Bio_Discharge_Summary_BERT_n", "PROC_ICD9", True)

# %%
graph.micro_performance_plot("../BERT/Bio_Discharge_Summary_BERT_n", "DIAG_ICD9", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "CPT_CD")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "DRG_CODE")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "DIAG_ICD9")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "CPT_CD")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "DRG_CODE")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "PROC_ICD9")

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "CPT_CD", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "DRG_CODE", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "PROC_ICD9", "DIAG_ICD9", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "CPT_CD", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "DRG_CODE", True)

# %%
graph.label_performance_change("../BERT/Bio_Discharge_Summary_BERT_n", "../utils/balance", "../baseline_xgb/correlation", "DIAG_ICD9", "PROC_ICD9", True)
